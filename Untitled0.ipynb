# %%
# 1. Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Plot Style
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (10,6)



df = pd.read_csv("DataCoSupplyChainDataset.csv", encoding='latin1')

print("\nDataset Loaded Successfully!")

# ============================================================
# 3. Display Basic Information
# ============================================================

print("\nFirst 5 Rows")
print(df.head())

print("\nLast 5 Rows")
print(df.tail())

print("\nDataset Shape")
print(df.shape)

print("\nColumn Names")
print(df.columns.tolist())

print("\nDataset Information")
print(df.info())

print("\nData Types")
print(df.dtypes)

# ============================================================
# 4. Summary Statistics
# ============================================================

print("\nSummary Statistics")
print(df.describe(include='all'))

# ============================================================
# 5. Missing Values
# ============================================================

print("\nMissing Values")
print(df.isnull().sum())

# Fill numerical missing values
numeric_columns = df.select_dtypes(include=np.number).columns

for col in numeric_columns:
    df[col].fillna(df[col].median(), inplace=True)

# Fill categorical missing values
categorical_columns = df.select_dtypes(include='object').columns

for col in categorical_columns:
    df[col].fillna(df[col].mode()[0], inplace=True)

print("\nMissing Values After Cleaning")
print(df.isnull().sum())

# ============================================================
# 6. Duplicate Records
# ============================================================

print("\nDuplicate Rows:", df.duplicated().sum())

df.drop_duplicates(inplace=True)

print("Dataset Shape After Removing Duplicates:", df.shape)

# ============================================================
# 7. Convert Data Types (if needed)
# ============================================================

date_columns = [col for col in df.columns if "date" in col.lower()]

for col in date_columns:
    try:
        df[col] = pd.to_datetime(df[col])
    except:
        pass

# ============================================================
# 8. Correlation Matrix
# ============================================================

numeric_df = df.select_dtypes(include=np.number)

plt.figure(figsize=(14,10))
sns.heatmap(
    numeric_df.corr(),
    annot=True,
    cmap='coolwarm',
    fmt=".2f"
)
plt.title("Correlation Heatmap")
plt.show()

# ============================================================
# 9. Histograms
# ============================================================

numeric_df.hist(figsize=(18,15))
plt.tight_layout()
plt.show()

# ============================================================
# 10. Boxplots
# ============================================================

for col in numeric_df.columns:

    plt.figure(figsize=(8,4))
    sns.boxplot(x=df[col])

    plt.title(f"Boxplot of {col}")
    plt.show()

# ============================================================
# 11. Outlier Detection (IQR Method)
# ============================================================

print("\nOutlier Detection")

for col in numeric_df.columns:

    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)

    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = df[(df[col] < lower) | (df[col] > upper)]

    print(f"{col}: {len(outliers)} Outliers")

# ============================================================
# 12. Distribution Plots
# ============================================================

for col in numeric_df.columns:

    plt.figure(figsize=(8,5))

    sns.histplot(df[col], kde=True)

    plt.title(f"Distribution of {col}")

    plt.show()

# ============================================================
# 13. Count Plots (Categorical Columns)
# ============================================================

categorical_columns = df.select_dtypes(include='object').columns

for col in categorical_columns[:8]:

    plt.figure(figsize=(10,5))

    sns.countplot(
        y=df[col],
        order=df[col].value_counts().index[:10]
    )

    plt.title(f"Top Categories in {col}")

    plt.show()

# ============================================================
# 14. Value Counts
# ============================================================

print("\nCategorical Value Counts")

for col in categorical_columns[:5]:

    print("\n-------------------------")
    print(col)
    print(df[col].value_counts().head(10))

# ============================================================
# 15. Pair Plot
# ============================================================

sample_numeric = numeric_df.iloc[:, :5]

sns.pairplot(sample_numeric)

plt.show()

# ============================================================
# 16. Skewness
# ============================================================

print("\nSkewness")

print(numeric_df.skew())

# ============================================================
# 17. Kurtosis
# ============================================================

print("\nKurtosis")

print(numeric_df.kurt())

# ============================================================
# 18. Unique Values
# ============================================================

print("\nUnique Values")

for col in df.columns:

    print(col, ":", df[col].nunique())

# ============================================================
# 19. Save Cleaned Dataset
# ============================================================

df.to_csv("Cleaned_SupplyChain_Dataset.csv", index=False)

print("\nCleaned Dataset Saved Successfully!")

# ============================================================
# 20. Final Report
# ============================================================

print("\n==============================")
print("EDA COMPLETED SUCCESSFULLY")
print("==============================")

print("Final Shape :", df.shape)

print("Missing Values :", df.isnull().sum().sum())

print("Duplicate Rows :", df.duplicated().sum())

print("Number of Columns :", len(df.columns))

print("Number of Numerical Columns :", len(numeric_df.columns))

print("Number of Categorical Columns :", len(categorical_columns))

print("==============================")
# Out:
# Dataset Loaded Successfully!
#
# First 5 Rows
#    warehouse_inventory_level  handling_equipment_availability  \
# 0                 985.716862                         0.481294
# 1                 985.716862                         0.481294
# 2                 985.716862                         0.481294
# 3                 396.700206                         0.620780
# 4                 396.700206                         0.620780
#
#    order_fulfillment_status  weather_condition_severity  shipping_costs  \
# 0                  0.761166                    0.359066      456.503853
# 1                  0.761166                    0.359066      456.503853
# 2                  0.761166                    0.359066      456.503853
# 3                  0.196594                    0.230660      640.408205
# 4                  0.196594                    0.230660      640.408205
#
#    supplier_reliability_score  lead_time_days  historical_demand  \
# 0                    0.986064        2.128009         100.772854
# 1                    0.986064        2.128009         100.772854
# 2                    0.986064        2.128009         100.772854
# 3                    0.463233       12.608166        5313.738114
# 4                    0.463233       12.608166        5313.738114
#
#    cargo_condition_status  route_risk_level  customs_clearance_time  \
# 0                0.777263          1.182116                0.502006
# 1                0.777263          1.182116                0.502006
# 2                0.777263          1.182116                0.502006
# 3                0.091839          9.611988                0.966774
# 4                0.091839          9.611988                0.966774
#
#    disruption_likelihood_score  delay_probability risk_classification  \
# 0                     0.506152           0.885291       Moderate Risk
# 1                     0.506152           0.885291       Moderate Risk
# 2                     0.506152           0.885291       Moderate Risk
# 3                     0.980784           0.544178           High Risk
# 4                     0.980784           0.544178           High Risk
#
#    delivery_time_deviation product_id supplier_id supplier_country
# 0                 9.110682      P0353    P0353_S1           Greece
# 1                 9.110682      P0353    P0353_S2      South Korea
# 2                 9.110682      P0353    P0353_S3         Ethiopia
# 3                 8.175281      P0857    P0857_S1             Iran
# 4                 8.175281      P0857    P0857_S2        Guatemala
#
# Last 5 Rows
#        warehouse_inventory_level  handling_equipment_availability  \
# 78042                 547.580501                         0.000002
# 78043                 547.580501                         0.000002
# 78044                 547.580501                         0.000002
# 78045                 478.849502                         0.587754
# 78046                 478.849502                         0.587754
#
#        order_fulfillment_status  weather_condition_severity  shipping_costs  \
# 78042                  0.590429                    0.030535      106.101386
# 78043                  0.590429                    0.030535      106.101386
# 78044                  0.590429                    0.030535      106.101386
# 78045                  0.999110                    0.442751      428.152399
# 78046                  0.999110                    0.442751      428.152399
#
#        supplier_reliability_score  lead_time_days  historical_demand  \
# 78042                    0.050629        2.814822        1944.833286
# 78043                    0.050629        2.814822        1944.833286
# 78044                    0.050629        2.814822        1944.833286
# 78045                    0.463112        1.090612        1878.821723
# 78046                    0.463112        1.090612        1878.821723
#
#        cargo_condition_status  route_risk_level  customs_clearance_time  \
# 78042                0.632138          5.942721                2.633309
# 78043                0.632138          5.942721                2.633309
# 78044                0.632138          5.942721                2.633309
# 78045                0.556666          9.594210                0.645102
# 78046                0.556666          9.594210                0.640000
#
#        disruption_likelihood_score  delay_probability risk_classification  \
# 78042                     0.956063           0.091112           High Risk
# 78043                     0.956063           0.091112           High Risk
# 78044                     0.956063           0.091112           High Risk
# 78045                     0.152299           0.996538            Low Risk
# 78046                          NaN                NaN                 NaN
#
#        delivery_time_deviation product_id supplier_id supplier_country
# 78042                -1.768624      P0541    P0541_S1          Tunisia
# 78043                -1.768624      P0541    P0541_S2            Nepal
# 78044                -1.768624      P0541    P0541_S3             Peru
# 78045                 8.937211      P0121    P0121_S1           Russia
# 78046                      NaN        NaN         NaN              NaN
#
# Dataset Shape
# (78047, 18)
#
# Column Names
# ['warehouse_inventory_level', 'handling_equipment_availability', 'order_fulfillment_status', 'weather_condition_severity', 'shipping_costs', 'supplier_reliability_score', 'lead_time_days', 'historical_demand', 'cargo_condition_status', 'route_risk_level', 'customs_clearance_time', 'disruption_likelihood_score', 'delay_probability', 'risk_classification', 'delivery_time_deviation', 'product_id', 'supplier_id', 'supplier_country']
#
# Dataset Information
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78047 entries, 0 to 78046
# Data columns (total 18 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   warehouse_inventory_level        78047 non-null  float64
#  1   handling_equipment_availability  78047 non-null  float64
#  2   order_fulfillment_status         78047 non-null  float64
#  3   weather_condition_severity       78047 non-null  float64
#  4   shipping_costs                   78047 non-null  float64
#  5   supplier_reliability_score       78047 non-null  float64
#  6   lead_time_days                   78047 non-null  float64
#  7   historical_demand                78047 non-null  float64
#  8   cargo_condition_status           78047 non-null  float64
#  9   route_risk_level                 78047 non-null  float64
#  10  customs_clearance_time           78047 non-null  float64
#  11  disruption_likelihood_score      78046 non-null  float64
#  12  delay_probability                78046 non-null  float64
#  13  risk_classification              78046 non-null  object
#  14  delivery_time_deviation          78046 non-null  float64
#  15  product_id                       78046 non-null  object
#  16  supplier_id                      78046 non-null  object
#  17  supplier_country                 78046 non-null  object
# dtypes: float64(14), object(4)
# memory usage: 10.7+ MB
# None
#
# Data Types
# warehouse_inventory_level          float64
# handling_equipment_availability    float64
# order_fulfillment_status           float64
# weather_condition_severity         float64
# shipping_costs                     float64
# supplier_reliability_score         float64
# lead_time_days                     float64
# historical_demand                  float64
# cargo_condition_status             float64
# route_risk_level                   float64
# customs_clearance_time             float64
# disruption_likelihood_score        float64
# delay_probability                  float64
# risk_classification                 object
# delivery_time_deviation            float64
# product_id                          object
# supplier_id                         object
# supplier_country                    object
# dtype: object
#
# Summary Statistics
#         warehouse_inventory_level  handling_equipment_availability  \
# count                7.804700e+04                     7.804700e+04
# unique                        NaN                              NaN
# top                           NaN                              NaN
# freq                          NaN                              NaN
# mean                 2.987931e+02                     3.045157e-01
# std                  3.233575e+02                     3.276339e-01
# min                  2.730000e-11                     4.570000e-16
# 25%                  1.577614e+01                     1.741008e-02
# 50%                  1.575574e+02                     1.587018e-01
# 75%                  5.383888e+02                     5.584256e-01
# max                  9.999970e+02                     9.999995e-01
#
#         order_fulfillment_status  weather_condition_severity  shipping_costs  \
# count               78047.000000                7.804700e+04    78047.000000
# unique                       NaN                         NaN             NaN
# top                          NaN                         NaN             NaN
# freq                         NaN                         NaN             NaN
# mean                    0.600180                4.999363e-01      458.294457
# std                     0.346270                3.534617e-01      312.423467
# min                     0.000001                4.540000e-09      100.000000
# 25%                     0.274279                1.455788e-01      153.204785
# 50%                     0.678418                5.030515e-01      384.281236
# 75%                     0.937889                8.532345e-01      752.081945
# max                     1.000000                1.000000e+00      999.999853
#
#         supplier_reliability_score  lead_time_days  historical_demand  \
# count                 7.804700e+04    78047.000000       78047.000000
# unique                         NaN             NaN                NaN
# top                            NaN             NaN                NaN
# freq                           NaN             NaN                NaN
# mean                  5.000644e-01        5.207325        6013.666842
# std                   3.531398e-01        4.522946        3428.912627
# min                   6.900000e-10        1.000000         100.002966
# 25%                   1.455985e-01        1.232074        2820.726822
# 50%                   5.012293e-01        3.246073        6782.754422
# 75%                   8.524590e-01        8.608576        9369.011425
# max                   1.000000e+00       14.999995        9999.999986
#
#         cargo_condition_status  route_risk_level  customs_clearance_time  \
# count             7.804700e+04      78047.000000            78047.000000
# unique                     NaN               NaN                     NaN
# top                        NaN               NaN                     NaN
# freq                       NaN               NaN                     NaN
# mean              2.981334e-01          6.983559                2.295901
# std               3.225300e-01          3.238269                1.553264
# min               2.570000e-17          0.000090                0.500000
# 25%               1.688862e-02          4.545121                0.779661
# 50%               1.546905e-01          8.368672                1.944934
# 75%               5.412103e-01          9.830142                3.737693
# max               1.000000e+00         10.000000                5.000000
#
#         disruption_likelihood_score  delay_probability risk_classification  \
# count                  78046.000000       78046.000000               78046
# unique                          NaN                NaN                   3
# top                             NaN                NaN           High Risk
# freq                            NaN                NaN               58031
# mean                       0.802027           0.702868                 NaN
# std                        0.280011           0.322249                 NaN
# min                        0.000117           0.000003                 NaN
# 25%                        0.688071           0.463666                 NaN
# 50%                        0.957109           0.843266                 NaN
# 75%                        0.998713           0.983064                 NaN
# max                        1.000000           1.000000                 NaN
#
#         delivery_time_deviation product_id supplier_id supplier_country
# count              78046.000000      78046       78046            78046
# unique                      NaN       1000        3524               94
# top                         NaN      P0210    P0517_S1          Vietnam
# freq                        NaN        175          38             1337
# mean                   5.176964        NaN         NaN              NaN
# std                    4.160051        NaN         NaN              NaN
# min                   -1.999998        NaN         NaN              NaN
# 25%                    1.271065        NaN         NaN              NaN
# 50%                    6.114426        NaN         NaN              NaN
# 75%                    9.252569        NaN         NaN              NaN
# max                   10.000000        NaN         NaN              NaN
#
# Missing Values
# warehouse_inventory_level          0
# handling_equipment_availability    0
# order_fulfillment_status           0
# weather_condition_severity         0
# shipping_costs                     0
# supplier_reliability_score         0
# lead_time_days                     0
# historical_demand                  0
# cargo_condition_status             0
# route_risk_level                   0
# customs_clearance_time             0
# disruption_likelihood_score        1
# delay_probability                  1
# risk_classification                1
# delivery_time_deviation            1
# product_id                         1
# supplier_id                        1
# supplier_country                   1
# dtype: int64
#
# Missing Values After Cleaning
# /tmp/ipykernel_1272/3508109688.py:57: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /tmp/ipykernel_1272/3508109688.py:63: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)
# warehouse_inventory_level          0
# handling_equipment_availability    0
# order_fulfillment_status           0
# weather_condition_severity         0
# shipping_costs                     0
# supplier_reliability_score         0
# lead_time_days                     0
# historical_demand                  0
# cargo_condition_status             0
# route_risk_level                   0
# customs_clearance_time             0
# disruption_likelihood_score        0
# delay_probability                  0
# risk_classification                0
# delivery_time_deviation            0
# product_id                         0
# supplier_id                        0
# supplier_country                   0
# dtype: int64
#
# Duplicate Rows: 0
# Dataset Shape After Removing Duplicates: (78047, 18)
# Outlier Detection
# warehouse_inventory_level: 0 Outliers
# handling_equipment_availability: 0 Outliers
# order_fulfillment_status: 0 Outliers
# weather_condition_severity: 0 Outliers
# shipping_costs: 0 Outliers
# supplier_reliability_score: 0 Outliers
# lead_time_days: 0 Outliers
# historical_demand: 0 Outliers
# cargo_condition_status: 0 Outliers
# route_risk_level: 0 Outliers
# customs_clearance_time: 0 Outliers
# disruption_likelihood_score: 5719 Outliers
# delay_probability: 0 Outliers
# delivery_time_deviation: 0 Outliers
# Categorical Value Counts
#
# -------------------------
# risk_classification
# risk_classification
# High Risk        58032
# Moderate Risk    12357
# Low Risk          7658
# Name: count, dtype: int64
#
# -------------------------
# product_id
# product_id
# P0210    176
# P0515    170
# P0459    165
# P0711    160
# P0872    160
# P0712    160
# P0852    160
# P0084    155
# P0969    155
# P0520    155
# Name: count, dtype: int64
#
# -------------------------
# supplier_id
# supplier_id
# P0517_S1    39
# P0517_S2    38
# P0437_S1    35
# P0210_S5    35
# P0637_S1    35
# P0637_S2    35
# P0637_S3    35
# P0210_S4    35
# P0210_S3    35
# P0210_S2    35
# Name: count, dtype: int64
#
# -------------------------
# supplier_country
# supplier_country
# Vietnam                1338
# Dominican Republic     1238
# Trinidad and Tobago    1189
# UK                     1099
# Australia              1068
# Kyrgyzstan             1064
# Philippines            1056
# Bulgaria               1052
# Colombia               1034
# Jordan                 1030
# Name: count, dtype: int64
# Skewness
# warehouse_inventory_level          0.834577
# handling_equipment_availability    0.799046
# order_fulfillment_status          -0.382975
# weather_condition_severity        -0.001425
# shipping_costs                     0.395559
# supplier_reliability_score        -0.005090
# lead_time_days                     0.816816
# historical_demand                 -0.377554
# cargo_condition_status             0.836182
# route_risk_level                  -0.815726
# customs_clearance_time             0.384014
# disruption_likelihood_score       -1.421683
# delay_probability                 -0.845455
# delivery_time_deviation           -0.378334
# dtype: float64
#
# Kurtosis
# warehouse_inventory_level         -0.707057
# handling_equipment_availability   -0.803703
# order_fulfillment_status          -1.336796
# weather_condition_severity        -1.502622
# shipping_costs                    -1.328788
# supplier_reliability_score        -1.501945
# lead_time_days                    -0.740877
# historical_demand                 -1.336344
# cargo_condition_status            -0.708317
# route_risk_level                  -0.744237
# customs_clearance_time            -1.329203
# disruption_likelihood_score        0.792269
# delay_probability                 -0.694417
# delivery_time_deviation           -1.337240
# dtype: float64
#
# Unique Values
# warehouse_inventory_level : 22110
# handling_equipment_availability : 21897
# order_fulfillment_status : 22105
# weather_condition_severity : 22110
# shipping_costs : 22114
# supplier_reliability_score : 22114
# lead_time_days : 22079
# historical_demand : 22118
# cargo_condition_status : 21849
# route_risk_level : 22078
# customs_clearance_time : 22117
# disruption_likelihood_score : 21191
# delay_probability : 21984
# risk_classification : 3
# delivery_time_deviation : 22114
# product_id : 1000
# supplier_id : 3524
# supplier_country : 94
#
# Cleaned Dataset Saved Successfully!
#
# ==============================
# EDA COMPLETED SUCCESSFULLY
# ==============================
# Final Shape : (78047, 18)
# Missing Values : 0
# Duplicate Rows : 0
# Number of Columns : 18
# Number of Numerical Columns : 14
# Number of Categorical Columns : 4
# ==============================
